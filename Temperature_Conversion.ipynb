# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya-ayasi/Soft-Computing-Implementation/blob/main/Temperature_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the necessary packages
import tensorflow as tf  
import numpy as np
from tensorflow import keras
# Keras is a framework for defining a neural net as a set of sequential layers.

# %%
#code necessary to define the neural network
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# one layer with one neuron and the shape to it has only one value
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
#loss function: measures the guessed answers against the known correct answers and measures the accuracy
#optimizer function: based on the loss function, it tries to minimize the the loss. 
celsius = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)
#training data of temperature values

# %%
#code necessary to train the neural net
history= model.fit(celsius, fahrenheit, epochs=500)
#This is the process of training the NN. It goes through the loop, measuring loss and optimizing, for the number of epochs specified.
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 256ms/step - loss: 2076.2092
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1917.8466
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1771.2422
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1636.5631
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1513.9170
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1403.3347
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1304.7616
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1218.0460
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1142.9247
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1079.0137
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1025.7990
# Epoch 12/500
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
#A number can be input, to test the model
test = float(input("Enter a temperature value in Celsius "))
#prints the value of Fahrenheit for the test temperature.
print(model.predict([test]))
# Out:
# Enter a temperature value in Celsius 25
# [[74.720825]]
